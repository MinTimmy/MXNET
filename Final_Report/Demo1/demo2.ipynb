# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_dog = cv2.imread('images/dog.jpg')
img_dog = cv2.cvtColor(img_dog, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (20, 20))
plt.subplot(1, 2, 1); plt.imshow(img_dog)
img_dog.shape

img_street = cv2.imread('images/street_small.jpg')
img_street = cv2.cvtColor(img_street, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (20, 20))
plt.subplot(1, 2, 1); plt.imshow(img_street)
img_street.shape

# %%
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt
net = model_zoo.get_model('ssd_512_resnet50_v1_voc', pretrained=True)

im_fname = utils.download('https://raw.githubusercontent.com/zhreshold/' +
                          'mxnet-ssd/master/data/demo/dog.jpg',
                          path='dog.jpg')
x, img = data.transforms.presets.yolo.load_test(im_fname, short=512)
print('Shape of pre-processed image:', x.shape)





# class_IDs, scores, bounding_boxs = net(x)

# ax = utils.viz.plot_bbox(img, bounding_boxs[0], scores[0],
#                          class_IDs[0], class_names=net.classes) # scores[0],
# plt.show()

# %%
im_fname1 = utils.download('https://github.com/dmlc/web-data/blob/master/' +
                          'gluoncv/detection/street_small.jpg?raw=true',
                          path='street_small.jpg')
x, img1 = data.transforms.presets.ssd.load_test(im_fname1, short=512)
print('Shape of pre-processed image:', x.shape)

class_IDs, scores, bounding_boxs = net(x)

ax = utils.viz.plot_bbox(img, bounding_boxs[0], scores[0],
                         class_IDs[0], class_names=net.classes) # scores[0],
plt.show()
# Out:
# Shape of pre-processed image: (1, 3, 512, 512)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt
net = model_zoo.get_model('ssd_512_resnet50_v1_voc', pretrained=True)


# img_1 = cv2.imread('1.jpg')
# plt.figure(figsize = (20, 20))
# plt.subplot(1, 2, 1); plt.imshow(img_1)
# img_1.shape
# img_dog = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

# x, img_street = data.transforms.presets.ssd.load_test(img_1, short=512)
x, img_1 = data.transforms.presets.ssd.load_test('2.jpg', short=512)
print('Shape of pre-processed image:', x.shape)

class_IDs, scores, bounding_boxs = net(x)

ax = utils.viz.plot_bbox(img_1, bounding_boxs[0], scores[0],
                         class_IDs[0], class_names=net.classes) # scores[0],
plt.show()
# Out:
# Shape of pre-processed image: (1, 3, 512, 683)
